# %% [markdown]
# Przedmiot: Podstawy Reprezenracji i Analizy Danych
# Autorzy: Oliwia Gruda, Tomasz Wolszczak
# Data: 31.01.2026
# Zbiór danych: Spam Emails
# Zadania do wykonania: ?
#
# Celem niniejszego projektu była implementacja i ocena odelu uczenia maszynowego służącego do klasyfikacji wiadomości e-mail. Głównym problemem była skuteczna separacja wiadomości niechcianych (spam) od wiadomości wartościowych (real)
